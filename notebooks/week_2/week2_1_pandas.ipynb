# %%
import pandas as pd

# %%
frame = pd.DataFrame({'numbers': range(10), 'chars': ['aa']*10})
frame
# Out:
#    numbers chars
# 0        0    aa
# 1        1    aa
# 2        2    aa
# 3        3    aa
# 4        4    aa
# 5        5    aa
# 6        6    aa
# 7        7    aa
# 8        8    aa
# 9        9    aa

# %%
week_root = '/opt/notebooks/week_2'
import os
frame = pd.read_csv(os.path.join(week_root, 'prepared/dataset.tsv'), header=0, sep='\t')
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер

# %%
frame.shape
# Out:
# (6, 4)

# %%
frame.__doc__
# Out:
# " Two-dimensional size-mutable, potentially heterogeneous tabular data\n    structure with labeled axes (rows and columns). Arithmetic operations\n    align on both row and column labels. Can be thought of as a dict-like\n    container for Series objects. The primary pandas data structure.\n\n    Parameters\n    ----------\n    data : numpy ndarray (structured or homogeneous), dict, or DataFrame\n        Dict can contain Series, arrays, constants, or list-like objects\n\n        .. versionchanged :: 0.23.0\n           If data is a dict, argument order is maintained for Python 3.6\n           and later.\n\n    index : Index or array-like\n        Index to use for resulting frame. Will default to RangeIndex if\n        no indexing information part of input data and no index provided\n    columns : Index or array-like\n        Column labels to use for resulting frame. Will default to\n        RangeIndex (0, 1, 2, ..., n) if no column labels are provided\n    dtype : dtype, default None\
# ...

# %%
new_line = {'Name':'Perov', 'Birth':'22.03.1990', 'City':'Penza'}
frame.append(new_line, ignore_index=True)
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6            Perov  22.03.1990      Penza       NaN

# %%
aa = {'Name':'Perov2', 'Birth':'22.03.1990000', 'City':'Penza2'}
frame = frame.append(aa, ignore_index=True)
frame
# Out:
#               Name          Birth       City  Position
# 0      Иванов А.А.     22.03.1980     Москва       NaN
# 1     Сорокин И.В.     07.08.1965  Волгоград   инженер
# 2       Белов М.М.     13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.     15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.     19.11.1985     Москва   инженер
# 5     Костров С.О.     31.05.1985     Москва    стажер
# 6           Perov2  22.03.1990000     Penza2       NaN

# %%
frame
# Out:
#               Name          Birth       City  Position
# 0      Иванов А.А.     22.03.1980     Москва       NaN
# 1     Сорокин И.В.     07.08.1965  Волгоград   инженер
# 2       Белов М.М.     13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.     15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.     19.11.1985     Москва   инженер
# 5     Костров С.О.     31.05.1985     Москва    стажер
# 6           Perov2  22.03.1990000     Penza2       NaN

# %%
frame['IsStudent'] = [False]*5 + [True]*2
frame
# Out:
#               Name          Birth       City  Position  IsStudent
# 0      Иванов А.А.     22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.     07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.     13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.     15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.     19.11.1985     Москва   инженер      False
# 5     Костров С.О.     31.05.1985     Москва    стажер       True
# 6           Perov2  22.03.1990000     Penza2       NaN       True

# %%
frame.drop([5,6], axis=0)
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False

# %%
frame
# Out:
#               Name          Birth       City  Position  IsStudent
# 0      Иванов А.А.     22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.     07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.     13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.     15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.     19.11.1985     Москва   инженер      False
# 5     Костров С.О.     31.05.1985     Москва    стажер       True
# 6           Perov2  22.03.1990000     Penza2       NaN       True

# %%
frame = frame.drop([5,6], axis=0)
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False

# %%
frame.drop(['IsStudent'], axis=1, inplace=True)
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер

# %%
frame.to_csv('upd_frame.csv')
frame.to_csv('upd_frame_2.csv', index=None, sep='\t')
